# %% [markdown]
# ## 1. Data Loading

# %% [markdown]
# Ingestion of structured source data into analysis environment.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../data/fetal_health_data.csv")

# %% [markdown]
# Demonstrating loaded data.

# %%
df.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# 0                             73.0                                   0.5
# 1                             17.0                                   2.1
# 2                             16.0                                   2.1
# 3                             16.0                                   2.4
# 4                             16.0                                   2.4
#
#    percentage_of_time_with_abnormal_long_term_variability  ...  histogram_min  \
# 0                                               43.0       ...           62.0
# 1                                                0.0       ...           68.0
# 2                                                0.0       ...           68.0
# 3                                                0.0       ...           53.0
# 4                                                0.0       ...           53.0
#
#    histogram_max  histogram_number_of_peaks  histogram_number_of_zeroes  \
# 0          126.0                        2.0                         0.0
# 1          198.0                        6.0                         1.0
# 2          198.0                        5.0                         1.0
# 3          170.0                       11.0                         0.0
# 4          170.0                        9.0                         0.0
#
#    histogram_mode  histogram_mean  histogram_median  histogram_variance  \
# 0           120.0           137.0             121.0                73.0
# 1           141.0           136.0             140.0                12.0
# 2           141.0           135.0             138.0                13.0
# 3           137.0           134.0             137.0                13.0
# 4           137.0           136.0             138.0                11.0
#
#    histogram_tendency  fetal_health
# 0                 1.0           2.0
# 1                 0.0           1.0
# 2                 0.0           1.0
# 3                 1.0           1.0
# 4                 1.0           1.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 2. EXPLORATORY DATA ANALYSIS (EDA)

# %%
print(f"Dataset Shape: {df.shape}")
print(f"Features: {df.shape[1]-1}")
print(f"Samples: {df.shape[0]}")
# Out:
# Dataset Shape: (2126, 22)
# Features: 21
# Samples: 2126

# %%
print("Column Information:")
print(df.info())
# Out:
# Column Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
#  8   mean_value_of_short_term_variability                    2126 non-null   float64
#  9   percentage_of_time_with_abnormal_long_term_variability  2126 non-null   float64
#  10  mean_value_of_long_term_variability                     2126 non-null   float64
#  11  histogram_width                                         2126 non-null   float64
#  12  histogram_min                                           2126 non-null   float64
#  13  histogram_max                                           2126 non-null   float64
#  14  histogram_number_of_peaks                               2126 non-null   float64
#  15  histogram_number_of_zeroes                              2126 non-null   float64
#  16  histogram_mode                                          2126 non-null   float64
#  17  histogram_mean                                          2126 non-null   float64
#  18  histogram_median                                        2126 non-null   float64
#  19  histogram_variance                                      2126 non-null   float64
#  20  histogram_tendency                                      2126 non-null   float64
#  21  fetal_health                                            2126 non-null   float64
# dtypes: float64(22)
# memory usage: 365.5 KB
# None

# %%
print("Summary Statistics:")
print(df.describe().T)
# Out:
# Summary Statistics:
#                                                      count        mean  \
# baseline value                                      2126.0  133.303857
# accelerations                                       2126.0    0.003178
# fetal_movement                                      2126.0    0.009481
# uterine_contractions                                2126.0    0.004366
# light_decelerations                                 2126.0    0.001889
# severe_decelerations                                2126.0    0.000003
# prolongued_decelerations                            2126.0    0.000159
# abnormal_short_term_variability                     2126.0   46.990122
# mean_value_of_short_term_variability                2126.0    1.332785
# percentage_of_time_with_abnormal_long_term_vari...  2126.0    9.846660
# mean_value_of_long_term_variability                 2126.0    8.187629
# histogram_width                                     2126.0   70.445908
# histogram_min                                       2126.0   93.579492
# histogram_max                                       2126.0  164.025400
# histogram_number_of_peaks                           2126.0    4.068203
# histogram_number_of_zeroes                          2126.0    0.323612
# histogram_mode                                      2126.0  137.452023
# histogram_mean                                      2126.0  134.610536
# histogram_median                                    2126.0  138.090310
# histogram_variance                                  2126.0   18.808090
# histogram_tendency                                  2126.0    0.320320
# fetal_health                                        2126.0    1.304327
#
#                                                           std    min      25%  \
# baseline value                                       9.840844  106.0  126.000
# accelerations                                        0.003866    0.0    0.000
# fetal_movement                                       0.046666    0.0    0.000
# uterine_contractions                                 0.002946    0.0    0.002
# light_decelerations                                  0.002960    0.0    0.000
# severe_decelerations                                 0.000057    0.0    0.000
# prolongued_decelerations                             0.000590    0.0    0.000
# abnormal_short_term_variability                     17.192814   12.0   32.000
# mean_value_of_short_term_variability                 0.883241    0.2    0.700
# percentage_of_time_with_abnormal_long_term_vari...  18.396880    0.0    0.000
# mean_value_of_long_term_variability                  5.628247    0.0    4.600
# histogram_width                                     38.955693    3.0   37.000
# histogram_min                                       29.560212   50.0   67.000
# histogram_max                                       17.944183  122.0  152.000
# histogram_number_of_peaks                            2.949386    0.0    2.000
# histogram_number_of_zeroes                           0.706059    0.0    0.000
# histogram_mode                                      16.381289   60.0  129.000
# histogram_mean                                      15.593596   73.0  125.000
# histogram_median                                    14.466589   77.0  129.000
# histogram_variance                                  28.977636    0.0    2.000
# histogram_tendency                                   0.610829   -1.0    0.000
# fetal_health                                         0.614377    1.0    1.000
#
#                                                         50%      75%      max
# baseline value                                      133.000  140.000  160.000
# accelerations                                         0.002    0.006    0.019
# fetal_movement                                        0.000    0.003    0.481
# uterine_contractions                                  0.004    0.007    0.015
# light_decelerations                                   0.000    0.003    0.015
# severe_decelerations                                  0.000    0.000    0.001
# prolongued_decelerations                              0.000    0.000    0.005
# abnormal_short_term_variability                      49.000   61.000   87.000
# mean_value_of_short_term_variability                  1.200    1.700    7.000
# percentage_of_time_with_abnormal_long_term_vari...    0.000   11.000   91.000
# mean_value_of_long_term_variability                   7.400   10.800   50.700
# histogram_width                                      67.500  100.000  180.000
# histogram_min                                        93.000  120.000  159.000
# histogram_max                                       162.000  174.000  238.000
# histogram_number_of_peaks                             3.000    6.000   18.000
# histogram_number_of_zeroes                            0.000    0.000   10.000
# histogram_mode                                      139.000  148.000  187.000
# histogram_mean                                      136.000  145.000  182.000
# histogram_median                                    139.000  148.000  186.000
# histogram_variance                                    7.000   24.000  269.000
# histogram_tendency                                    0.000    1.000    1.000
# fetal_health                                          1.000    1.000    3.000

# %%
print("Missing Values:")
missing = df.isnull().sum()
missing_percent = (missing[missing > 0] / len(df)) * 100
if len(missing_percent) > 0:
    print(missing_percent)
else:
    print("No missing values found!")
# Out:
# Missing Values:
# No missing values found!

# %%
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_ebabb_row0_col0, #T_ebabb_row1_col1, #T_ebabb_row2_col2, #T_ebabb_row3_col3, #T_ebabb_row4_col4, #T_ebabb_row5_col5, #T_ebabb_row6_col6, #T_ebabb_row7_col7, #T_ebabb_row8_col8, #T_ebabb_row9_col9, #T_ebabb_row10_col10, #T_ebabb_row11_col11, #T_ebabb_row12_col12, #T_ebabb_row13_col13, #T_ebabb_row14_col14, #T_ebabb_row15_col15, #T_ebabb_row16_col16, #T_ebabb_row17_col17, #T_ebabb_row18_col18, #T_ebabb_row19_col19, #T_ebabb_row20_col20, #T_ebabb_row21_col21 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ebabb_row0_col1, #T_ebabb_row0_col8, #T_ebabb_row3_col18, #T_ebabb_row5_col10, #T_ebabb_row11_col5, #T_ebabb_row15_col0, #T_ebabb_row15_col5, #T_ebabb_row21_col2 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_ebabb_row0_col2, #T_ebabb_row3_col0, #T_ebabb_row10_col21, #T_ebabb_row11_col0, #T_ebabb_row17_col21, #T_ebabb_row19_col18 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_ebabb_row0_col3, #T_ebabb_row5_col2, #T_ebabb_row20_col13 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_ebabb_row0_col4, #T_ebabb_row2_col18, #T_ebabb_row15_col21 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_ebabb_row0_col5, #T_ebabb_row4_col9 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_ebabb_row0_col6, #T_ebabb_row2_col16, #T_ebabb_row7_col19 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_ebabb_row0_col7, #T_ebabb_row0_col9, #T_ebabb_row1_col14 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_ebabb_row0_col10, #T_ebabb_row1_col20, #T_ebabb_row4_col7, #T_ebabb_row5_col13, #T_ebabb_row11_col21 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_ebabb_row0_col11, #T_ebabb_row10_col12 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_ebabb_row0_col12, #T_ebabb_row12_col17 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_ebabb_row0_col13, #T_ebabb_row9_col0 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_ebabb_row0_col14, #T_ebabb_row6_col7, #T_ebabb_row15_col10, #T_ebabb_row21_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_ebabb_row0_col15, #T_ebabb_row3_col16, #T_ebabb_row9_col14, #T_ebabb_row10_col13, #T_ebabb_row13_col21, #T_ebabb_row14_col16 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_ebabb_row0_col16, #T_ebabb_row19_col11 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_ebabb_row0_col17 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_ebabb_row0_col18 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_ebabb_row0_col19, #T_ebabb_row2_col9, #T_ebabb_row5_col15, #T_ebabb_row15_col1 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_ebabb_row0_col20, #T_ebabb_row13_col0, #T_ebabb_row16_col9 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_ebabb_row0_col21, #T_ebabb_row13_col15 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_ebabb_row1_col0, #T_ebabb_row5_col16, #T_ebabb_row16_col3 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_ebabb_row1_col2 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_ebabb_row1_col3, #T_ebabb_row7_col14, #T_ebabb_row20_col19 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_ebabb_row1_col4, #T_ebabb_row2_col17, #T_ebabb_row18_col10, #T_ebabb_row19_col2, #T_ebabb_row21_col5 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_ebabb_row1_col5, #T_ebabb_row8_col20, #T_ebabb_row9_col15, #T_ebabb_row10_col2, #T_ebabb_row12_col6 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_ebabb_row1_col6 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_ebabb_row1_col7, #T_ebabb_row17_col8, #T_ebabb_row18_col4 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_ebabb_row1_col8, #T_ebabb_row13_col18, #T_ebabb_row18_col20 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_ebabb_row1_col9 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_ebabb_row1_col10, #T_ebabb_row12_col10, #T_ebabb_row14_col0, #T_ebabb_row14_col9, #T_ebabb_row16_col4, #T_ebabb_row19_col20, #T_ebabb_row20_col2, #T_ebabb_row21_col16 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_ebabb_row1_col11, #T_ebabb_row7_col9, #T_ebabb_row14_col13, #T_ebabb_row21_col7 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_ebabb_row1_col12, #T_ebabb_row2_col12, #T_ebabb_row7_col17, #T_ebabb_row7_col18, #T_ebabb_row21_col4 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_ebabb_row1_col13, #T_ebabb_row6_col14, #T_ebabb_row10_col11 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_ebabb_row1_col15, #T_ebabb_row2_col7, #T_ebabb_row9_col20 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_ebabb_row1_col16 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_ebabb_row1_col17 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_ebabb_row1_col18, #T_ebabb_row2_col14, #T_ebabb_row5_col11, #T_ebabb_row13_col4 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_ebabb_row1_col19, #T_ebabb_row5_col12, #T_ebabb_row9_col18, #T_ebabb_row10_col14, #T_ebabb_row10_col17, #T_ebabb_row21_col11 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_ebabb_row1_col21, #T_ebabb_row4_col17, #T_ebabb_row6_col16, #T_ebabb_row6_col18, #T_ebabb_row7_col10, #T_ebabb_row8_col0, #T_ebabb_row8_col7, #T_ebabb_row8_col9, #T_ebabb_row9_col1, #T_ebabb_row9_col3, #T_ebabb_row11_col12, #T_ebabb_row12_col2, #T_ebabb_row12_col4, #T_ebabb_row12_col8, #T_ebabb_row12_col11, #T_ebabb_row12_col13, #T_ebabb_row12_col14, #T_ebabb_row12_col15, #T_ebabb_row12_col19, #T_ebabb_row12_col20, #T_ebabb_row16_col5, #T_ebabb_row17_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ebabb_row2_col0, #T_ebabb_row2_col20, #T_ebabb_row4_col1, #T_ebabb_row4_col20, #T_ebabb_row10_col0, #T_ebabb_row11_col16, #T_ebabb_row16_col8, #T_ebabb_row18_col15 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_ebabb_row2_col1 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_ebabb_row2_col3, #T_ebabb_row3_col5, #T_ebabb_row4_col12, #T_ebabb_row9_col4, #T_ebabb_row14_col5, #T_ebabb_row20_col6 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_ebabb_row2_col4, #T_ebabb_row16_col11, #T_ebabb_row21_col14 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_ebabb_row2_col5, #T_ebabb_row9_col19, #T_ebabb_row10_col1, #T_ebabb_row17_col15, #T_ebabb_row20_col21 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_ebabb_row2_col6, #T_ebabb_row3_col19, #T_ebabb_row8_col6, #T_ebabb_row11_col6, #T_ebabb_row15_col4, #T_ebabb_row21_col12 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_ebabb_row2_col8, #T_ebabb_row7_col0, #T_ebabb_row17_col20, #T_ebabb_row18_col13 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_ebabb_row2_col10, #T_ebabb_row10_col19, #T_ebabb_row14_col21 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_ebabb_row2_col11, #T_ebabb_row3_col8, #T_ebabb_row13_col1, #T_ebabb_row20_col17 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_ebabb_row2_col13, #T_ebabb_row4_col21, #T_ebabb_row15_col12 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_ebabb_row2_col15, #T_ebabb_row3_col17, #T_ebabb_row13_col2, #T_ebabb_row21_col15 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_ebabb_row2_col19, #T_ebabb_row13_col17, #T_ebabb_row17_col1, #T_ebabb_row17_col9, #T_ebabb_row18_col1 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_ebabb_row2_col21, #T_ebabb_row10_col15, #T_ebabb_row13_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_ebabb_row3_col1, #T_ebabb_row5_col6, #T_ebabb_row7_col11 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_ebabb_row3_col2, #T_ebabb_row18_col2 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_ebabb_row3_col4 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_ebabb_row3_col6, #T_ebabb_row17_col13 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_ebabb_row3_col7, #T_ebabb_row3_col20, #T_ebabb_row5_col20, #T_ebabb_row6_col0 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_ebabb_row3_col9, #T_ebabb_row9_col10 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_ebabb_row3_col10, #T_ebabb_row7_col20, #T_ebabb_row8_col21, #T_ebabb_row11_col18, #T_ebabb_row16_col15 {
#   background-color: #dedcec;
#   col
